# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from utils.data import load_data
from utils.model import XGBModel
from utils.pipeline import pipeline, get_data

# %%
base, train, test, sample = load_data()

# %%
import xgboost
model = xgboost.XGBRegressor()

# %%
model = XGBModel({'max_depth': 7, 'n_estimators': 500})
pred, art = pipeline(model, train, base, test, 0.2)
# Out:
# Data processed
# (132821, 38) (132821,) (33206, 38) (33206,)
# [18:44:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:137855	validation_1-rmse:137014	validation_0-mape:88.9299	validation_1-mape:88.957
# [1]	validation_0-rmse:124987	validation_1-rmse:124227	validation_0-mape:79.0276	validation_1-mape:79.0583
# [2]	validation_0-rmse:113486	validation_1-rmse:112857	validation_0-mape:70.1292	validation_1-mape:70.1896
# [3]	validation_0-rmse:103127	validation_1-rmse:102620	validation_0-mape:62.289	validation_1-mape:62.3573
# [4]	validation_0-rmse:93910.3	validation_1-rmse:93515.3	validation_0-mape:55.3154	validation_1-mape:55.374
# [5]	validation_0-rmse:85594	validation_1-rmse:85297.6	validation_0-mape:49.2956	validation_1-mape:49.3289
# [6]	validation_0-rmse:78197.1	validation_1-rmse:78010.3	validation_0-mape:44.136	validation_1-mape:44.1498
# ...

# %%
sample['avg_price_sqm'] = pred

# %%
sample.to_csv('data/500it.tsv', index=False, sep='\t')

# %%
sorted(zip(art['model'].model.feature_importances_, list(art['data'][0][0].columns)), reverse=True)
# Out:
# [(0.2573571, 'unique_active_building_series_count'),
#  (0.18923475, 'art_cnt'),
#  (0.16683272, 'total_area_avg'),
#  (0.06958539, 'offer_count'),
#  (0.042978402, 'has_elevator_mean'),
#  (0.036205836, 'MONOLIT_BRICK_mean'),
#  (0.02320764, 'ceiling_height_median'),
#  (0.019578656, 'build_year_median'),
#  (0.01630537, 'sport_cnt'),
#  (0.01436132, 'MONOLIT_mean'),
#  (0.01367472, 'expect_demolition_mean'),
#  (0.010869596, 'healthcare_cnt'),
#  (0.010864608, 'flats_count_median'),
#  (0.01023252, 'rooms_offered_1_ratio'),
#  (0.00949822, 'ceiling_height_mean'),
#  (0.007948924, 'BLOCK_mean'),
#  (0.0077146124, 'chain_cnt'),
#  (0.0073717562, 'flats_count_mean'),
#  (0.006985367, 'PANEL_mean'),
#  (0.006755616, 'cafe_restaurant_eating_out_cnt'),
#  (0.0067503317, 'apartment_ratio'),
#  (0.0061916267, 'unique_active_buildings_count'),
#  (0.0061198333, 'rooms_offered_4_more_ratio'),
#  (0.0057107955, 'beauty_cnt'),
#  (0.0057046902, 'rooms_offered_2_ratio'),
# ...
